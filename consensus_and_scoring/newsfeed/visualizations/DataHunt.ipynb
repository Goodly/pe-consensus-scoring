# %%
import json
import csv
import os
import glob
import pandas as pd
import numpy as np
import re
from collections import Counter

# %%
def read_csv_from_path(path):
    return pd.read_csv(path)

# %%
path =  'datahunts'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

raw_data = pd.concat(li, axis=0, ignore_index=True)

# %%
raw_data
# Out:
#                      namespace  \
# 0     Covid_Evidence2020_03_21
# 1     Covid_Evidence2020_03_21
# 2     Covid_Evidence2020_03_21
# 3     Covid_Evidence2020_03_21
# 4     Covid_Evidence2020_03_21
# ...                        ...
# 1245  Covid_Evidence2020_03_21
# 1246  Covid_Evidence2020_03_21
# 1247  Covid_Evidence2020_03_21
# 1248  Covid_Evidence2020_03_21
# 1249  Covid_Evidence2020_03_21
#
#                                           schema_sha256  \
# 0     45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 1     45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 2     45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 3     45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 4     45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# ...                                                 ...
# 1245  45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 1246  45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 1247  45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 1248  45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 1249  45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
#
#                             quiz_task_uuid  \
# 0     f7562d2d-e884-41f7-8d1c-5163848cb3bf
# 1     f7562d2d-e884-41f7-8d1c-5163848cb3bf
# 2     f7562d2d-e884-41f7-8d1c-5163848cb3bf
# 3     f7562d2d-e884-41f7-8d1c-5163848cb3bf
# 4     f7562d2d-e884-41f7-8d1c-5163848cb3bf
# ...                                    ...
# 1245  edb1510f-1923-4d6f-a678-95f53d752bea
# 1246  edb1510f-1923-4d6f-a678-95f53d752bea
# 1247  edb1510f-1923-4d6f-a678-95f53d752bea
# 1248  edb1510f-1923-4d6f-a678-95f53d752bea
# 1249  edb1510f-1923-4d6f-a678-95f53d752bea
#
#                                                task_url  \
# 0     https://pe.goodlylabs.org/project/Covid_Eviden...
# 1     https://pe.goodlylabs.org/project/Covid_Eviden...
# 2     https://pe.goodlylabs.org/project/Covid_Eviden...
# 3     https://pe.goodlylabs.org/project/Covid_Eviden...
# 4     https://pe.goodlylabs.org/project/Covid_Eviden...
# ...                                                 ...
# 1245  https://pe.goodlylabs.org/project/Covid_Eviden...
# 1246  https://pe.goodlylabs.org/project/Covid_Eviden...
# 1247  https://pe.goodlylabs.org/project/Covid_Eviden...
# 1248  https://pe.goodlylabs.org/project/Covid_Eviden...
# 1249  https://pe.goodlylabs.org/project/Covid_Eviden...
#
#                                   tua_uuid  \
# 0     e406cae2-6cbe-4c06-9ddb-1ed542b98221
# 1     e406cae2-6cbe-4c06-9ddb-1ed542b98221
# 2     e406cae2-6cbe-4c06-9ddb-1ed542b98221
# 3     e406cae2-6cbe-4c06-9ddb-1ed542b98221
# 4     e406cae2-6cbe-4c06-9ddb-1ed542b98221
# ...                                    ...
# 1245  a723537a-f11a-41dd-bf5b-668cef67a5de
# 1246  a723537a-f11a-41dd-bf5b-668cef67a5de
# 1247  a723537a-f11a-41dd-bf5b-668cef67a5de
# 1248  a723537a-f11a-41dd-bf5b-668cef67a5de
# 1249  a723537a-f11a-41dd-bf5b-668cef67a5de
#
#                                 article_batch_name  article_number  \
# 0     CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 1     CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 2     CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 3     CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 4     CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# ...                                            ...             ...
# 1245  CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 1246  CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 1247  CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 1248  CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 1249  CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
#
#                     article_filename  \
# 0     Covid_article_for_PE_S&S&S.txt
# 1     Covid_article_for_PE_S&S&S.txt
# 2     Covid_article_for_PE_S&S&S.txt
# 3     Covid_article_for_PE_S&S&S.txt
# 4     Covid_article_for_PE_S&S&S.txt
# ...                              ...
# 1245  Covid_article_for_PE_S&S&S.txt
# 1246  Covid_article_for_PE_S&S&S.txt
# 1247  Covid_article_for_PE_S&S&S.txt
# 1248  Covid_article_for_PE_S&S&S.txt
# 1249  Covid_article_for_PE_S&S&S.txt
#
#                                          article_sha256  article_text_length  \
# 0     4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 1     4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 2     4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 3     4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 4     4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# ...                                                 ...                  ...
# 1245  4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 1246  4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 1247  4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 1248  4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 1249  4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
#
#       ... answer_label                               answer_content  \
# 0     ...     T1.Q1.A1  General Causation (In general, X causes Y.)
# 1     ...     T1.Q2.A1                                  Correlation
# 2     ...     T1.Q2.A1                                  Correlation
# 3     ...     T1.Q4.A5                    Not at all representative
# 4     ...     T1.Q7.A1                  placeholder answer for TEXT
# ...   ...          ...                                          ...
# 1245  ...    T1.Q10.A5                                Very Unlikely
# 1246  ...    T1.Q11.A4                            Somewhat Unlikely
# 1247  ...    T1.Q12.A2                              Yes, implicitly
# 1248  ...    T1.Q13.A6                                            6
# 1249  ...    T1.Q14.A9                                            9
#
#                                answer_uuid  \
# 0     73d7a14a-9ec6-404c-b2b7-a55508af3b76
# 1     5a1fb1f4-d8b7-45c0-bce5-7d4c3b91c55f
# 2     5a1fb1f4-d8b7-45c0-bce5-7d4c3b91c55f
# 3     b0cd6daf-353b-4bc0-a1cd-1c305a361edd
# 4     682be4e9-7e39-45b2-82e6-9f6300bb173c
# ...                                    ...
# 1245  443d94fe-c0a2-4a8b-819f-9253a570f788
# 1246  6a8b58aa-2748-4697-995b-c1a34149f70d
# 1247  a0972088-cb65-4764-a4ee-3be2b2bd100a
# 1248  c296eb9d-def0-4a2e-91a4-f27215a4333c
# 1249  8193d6e2-9ccb-4993-a130-bfcc7c99dd85
#
#                         submitted_tua_uuid  \
# 0     af01d2a2-c51b-476d-899b-4c4596a1522e
# 1     35df5b25-b669-4599-a023-36a3e3863233
# 2     35df5b25-b669-4599-a023-36a3e3863233
# 3     f2e52d3c-6d40-48a8-a89b-dbcb990dffd8
# 4     d5b8320f-a73e-40d5-adc7-6acbdf343cbd
# ...                                    ...
# 1245  d0db2afe-8fba-4f2a-b0fc-86a9182a2627
# 1246  c934c5a4-eb4d-4fa5-9d7c-411d5d566b14
# 1247  bcb8cfd5-5a02-4c96-babe-8af03b0fa1e9
# 1248  3f7c3cfe-c478-4d76-a21a-d22e005c96a1
# 1249  0a6626fd-91fe-49e6-a76b-0cae2813f342
#
#                                             answer_text case_number  \
# 0           General Causation (In general, X causes Y.)           1
# 1                                           Correlation           1
# 2                                           Correlation           1
# 3                             Not at all representative           0
# 4     Even as the author says, secondary factors can...           0
# ...                                                 ...         ...
# 1245                                      Very Unlikely           0
# 1246                                  Somewhat Unlikely           0
# 1247                                    Yes, implicitly           1
# 1248                                                  6           0
# 1249                                                  9           0
#
#      highlight_count  start_pos end_pos  \
# 0                  1       3197    3311
# 1                  2       3375    3384
# 2                  2       3375    3528
# 3                  0          0       0
# 4                  0          0       0
# ...              ...        ...     ...
# 1245               0          0       0
# 1246               0          0       0
# 1247               1       1023    1106
# 1248               0          0       0
# 1249               0          0       0
#
#                                             target_text
# 0     Health problems associated with social isolati...
# 1                                             secondary
# 2     secondary effects of the pandemic, such as rec...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1245                                                NaN
# 1246                                                NaN
# 1247  Research on the psychological toll of social d...
# 1248                                                NaN
# 1249                                                NaN
#
# [1250 rows x 31 columns]

# %%
raw_data["article_number"].unique()
# Out:
# array([100059])

# %%
raw_data[(raw_data["start_pos"] == 0) & (raw_data["end_pos"] == 0)].head()
# Out:
#                   namespace  \
# 3  Covid_Evidence2020_03_21
# 4  Covid_Evidence2020_03_21
# 5  Covid_Evidence2020_03_21
# 6  Covid_Evidence2020_03_21
# 7  Covid_Evidence2020_03_21
#
#                                        schema_sha256  \
# 3  45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 4  45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 5  45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 6  45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 7  45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
#
#                          quiz_task_uuid  \
# 3  f7562d2d-e884-41f7-8d1c-5163848cb3bf
# 4  f7562d2d-e884-41f7-8d1c-5163848cb3bf
# 5  f7562d2d-e884-41f7-8d1c-5163848cb3bf
# 6  f7562d2d-e884-41f7-8d1c-5163848cb3bf
# 7  f7562d2d-e884-41f7-8d1c-5163848cb3bf
#
#                                             task_url  \
# 3  https://pe.goodlylabs.org/project/Covid_Eviden...
# 4  https://pe.goodlylabs.org/project/Covid_Eviden...
# 5  https://pe.goodlylabs.org/project/Covid_Eviden...
# 6  https://pe.goodlylabs.org/project/Covid_Eviden...
# 7  https://pe.goodlylabs.org/project/Covid_Eviden...
#
#                                tua_uuid  \
# 3  e406cae2-6cbe-4c06-9ddb-1ed542b98221
# 4  e406cae2-6cbe-4c06-9ddb-1ed542b98221
# 5  e406cae2-6cbe-4c06-9ddb-1ed542b98221
# 6  e406cae2-6cbe-4c06-9ddb-1ed542b98221
# 7  e406cae2-6cbe-4c06-9ddb-1ed542b98221
#
#                              article_batch_name  article_number  \
# 3  CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 4  CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 5  CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 6  CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 7  CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
#
#                  article_filename  \
# 3  Covid_article_for_PE_S&S&S.txt
# 4  Covid_article_for_PE_S&S&S.txt
# 5  Covid_article_for_PE_S&S&S.txt
# 6  Covid_article_for_PE_S&S&S.txt
# 7  Covid_article_for_PE_S&S&S.txt
#
#                                       article_sha256  article_text_length  \
# 3  4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 4  4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 5  4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 6  4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 7  4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
#
#    ... answer_label                  answer_content  \
# 3  ...     T1.Q4.A5       Not at all representative
# 4  ...     T1.Q7.A1     placeholder answer for TEXT
# 5  ...     T1.Q8.A1  Much more likely than author’s
# 6  ...     T1.Q9.A3                              No
# 7  ...    T1.Q12.A4                  No, not at all
#
#                             answer_uuid                    submitted_tua_uuid  \
# 3  b0cd6daf-353b-4bc0-a1cd-1c305a361edd  f2e52d3c-6d40-48a8-a89b-dbcb990dffd8
# 4  682be4e9-7e39-45b2-82e6-9f6300bb173c  d5b8320f-a73e-40d5-adc7-6acbdf343cbd
# 5  4aa8619b-1f36-468d-8fac-271257a983c2  bef6a1b3-f835-4c80-87b7-3cebf63abf15
# 6  27ebbcb0-94fa-4477-8644-af3f6c9ea03b  27e1e746-3851-497d-8988-a6eb671339b8
# 7  e2e6a7d3-ad12-4ba6-ab81-f7f73bc68a83  255e38cf-f23b-47ee-b15c-dee935e044c0
#
#                                          answer_text case_number  \
# 3                          Not at all representative           0
# 4  Even as the author says, secondary factors can...           0
# 5                     Much more likely than author’s           0
# 6                                                 No           0
# 7                                     No, not at all           0
#
#   highlight_count  start_pos end_pos target_text
# 3               0          0       0         NaN
# 4               0          0       0         NaN
# 5               0          0       0         NaN
# 6               0          0       0         NaN
# 7               0          0       0         NaN
#
# [5 rows x 31 columns]

# %%
raw_data[(raw_data["start_pos"] == -1) & (raw_data["end_pos"] == -1)].head()
# Out:
# Empty DataFrame
# Columns: [namespace, schema_sha256, quiz_task_uuid, task_url, tua_uuid, article_batch_name, article_number, article_filename, article_sha256, article_text_length, destination, task_redundancy, taskrun_count, quiz_taskrun_uuid, contributor_uuid, created, finish_time, elapsed_seconds, topic_name, question_label, question_text, answer_label, answer_content, answer_uuid, submitted_tua_uuid, answer_text, case_number, highlight_count, start_pos, end_pos, target_text]
# Index: []
#
# [0 rows x 31 columns]

# %%
raw_data.columns
# Out:
# Index(['namespace', 'schema_sha256', 'quiz_task_uuid', 'task_url', 'tua_uuid',
#        'article_batch_name', 'article_number', 'article_filename',
#        'article_sha256', 'article_text_length', 'destination',
#        'task_redundancy', 'taskrun_count', 'quiz_taskrun_uuid',
#        'contributor_uuid', 'created', 'finish_time', 'elapsed_seconds',
#        'topic_name', 'question_label', 'question_text', 'answer_label',
#        'answer_content', 'answer_uuid', 'submitted_tua_uuid', 'answer_text',
#        'case_number', 'highlight_count', 'start_pos', 'end_pos',
#        'target_text'],
#       dtype='object')

# %%
clean_data = raw_data[["contributor_uuid", "article_sha256", "article_number", "question_text", "answer_text", "start_pos", "end_pos"]]
clean_data.head(3)
# Out:
#                        contributor_uuid  \
# 0  85579cf2-e01c-45c5-b9e7-34b40467148d
# 1  85579cf2-e01c-45c5-b9e7-34b40467148d
# 2  85579cf2-e01c-45c5-b9e7-34b40467148d
#
#                                       article_sha256  article_number  \
# 0  4b537e0ed21179a29ed28da28057d338e67330ae12123c...          100059
# 1  4b537e0ed21179a29ed28da28057d338e67330ae12123c...          100059
# 2  4b537e0ed21179a29ed28da28057d338e67330ae12123c...          100059
#
#                                        question_text  \
# 0  Is a general or singular causal claim made? Hi...
# 1  What evidence is given for the primary causal ...
# 2  What evidence is given for the primary causal ...
#
#                                    answer_text  start_pos  end_pos
# 0  General Causation (In general, X causes Y.)       3197     3311
# 1                                  Correlation       3375     3384
# 2                                  Correlation       3375     3528

# %% [markdown]
# ## Select Functions

# %%
# Selects rows with the inputted user_id. 
def select_user_id(df, user_id):
    return df[df["contributor_uuid"] == user_id]

# %%
# Selects rows with the inputted article_id. 
def select_article_id(df, article_id):
    return df[df["article_number"] == article_id]

# %%
# Takes out invalid start_pos and end_pos indices from the dataframe. 
def select_valid_indices(df):
    return df[(df["start_pos"] != 0) | (df["start_pos"] != -1) | (df["end_pos"] != 0) | (df["start_pos"] != -1)]

# %% [markdown]
# ## Convert to CSV

# %%
# Converts dataframe to CSV.
def convert_to_csv(df, category, arg):
    if category == "user_id":
        df = select_user_id(df, arg)
        name = str(df["contributor_uuid"][0])
    elif category == "article_id":
        df = select_article_id(df, arg)
        name = str(df["article_number"][0])
    elif category == "valid_indices":
        df = select_valid_indices(df)
        name = "valid"
    else:
        raise ValueError("Invalid category type")
        
    # "[articleid]_[userid]_user_contributions.csv"
    df.to_csv("aggregate_datahunts/" + name + "_user_contributions.csv")

# %%
# Converts dataframe to CSV, putting article_number and contributor_uuid in the name. 
def convert_to_csv_user_article(df, user_id, article_id):
    df = select_user_id(df, user_id)
    df = select_article_id(df, article_id)
    df = select_valid_indices(df)
    name = str(df["article_number"][0]) + "_" + str(df["contributor_uuid"][0])
    df.to_csv("aggregate_datahunts/" + name + "_user_contributions.csv")

# %% [markdown]
# ### Test

# %%
select_article_id(clean_data, 100059).head(3)
# Out:
#                        contributor_uuid  \
# 0  85579cf2-e01c-45c5-b9e7-34b40467148d
# 1  85579cf2-e01c-45c5-b9e7-34b40467148d
# 2  85579cf2-e01c-45c5-b9e7-34b40467148d
#
#                                       article_sha256  article_number  \
# 0  4b537e0ed21179a29ed28da28057d338e67330ae12123c...          100059
# 1  4b537e0ed21179a29ed28da28057d338e67330ae12123c...          100059
# 2  4b537e0ed21179a29ed28da28057d338e67330ae12123c...          100059
#
#                                        question_text  \
# 0  Is a general or singular causal claim made? Hi...
# 1  What evidence is given for the primary causal ...
# 2  What evidence is given for the primary causal ...
#
#                                    answer_text  start_pos  end_pos
# 0  General Causation (In general, X causes Y.)       3197     3311
# 1                                  Correlation       3375     3384
# 2                                  Correlation       3375     3528

# %%
convert_to_csv(clean_data, "article_id", 100059)

# %%
convert_to_csv(clean_data, "user_id", "85579cf2-e01c-45c5-b9e7-34b40467148d")

# %%
clean_data[clean_data["article_number"] == 2005]
# Out:
# Empty DataFrame
# Columns: [contributor_uuid, article_sha256, article_number, question_text, answer_text, start_pos, end_pos]
# Index: []

# %%
clean_data
# Out:
#                           contributor_uuid  \
# 0     85579cf2-e01c-45c5-b9e7-34b40467148d
# 1     85579cf2-e01c-45c5-b9e7-34b40467148d
# 2     85579cf2-e01c-45c5-b9e7-34b40467148d
# 3     85579cf2-e01c-45c5-b9e7-34b40467148d
# 4     85579cf2-e01c-45c5-b9e7-34b40467148d
# ...                                    ...
# 1245  bd786026-bad5-4fa8-9a3a-38ca03a16412
# 1246  bd786026-bad5-4fa8-9a3a-38ca03a16412
# 1247  bd786026-bad5-4fa8-9a3a-38ca03a16412
# 1248  bd786026-bad5-4fa8-9a3a-38ca03a16412
# 1249  bd786026-bad5-4fa8-9a3a-38ca03a16412
#
#                                          article_sha256  article_number  \
# 0     4b537e0ed21179a29ed28da28057d338e67330ae12123c...          100059
# 1     4b537e0ed21179a29ed28da28057d338e67330ae12123c...          100059
# 2     4b537e0ed21179a29ed28da28057d338e67330ae12123c...          100059
# 3     4b537e0ed21179a29ed28da28057d338e67330ae12123c...          100059
# 4     4b537e0ed21179a29ed28da28057d338e67330ae12123c...          100059
# ...                                                 ...             ...
# 1245  4b537e0ed21179a29ed28da28057d338e67330ae12123c...          100059
# 1246  4b537e0ed21179a29ed28da28057d338e67330ae12123c...          100059
# 1247  4b537e0ed21179a29ed28da28057d338e67330ae12123c...          100059
# 1248  4b537e0ed21179a29ed28da28057d338e67330ae12123c...          100059
# 1249  4b537e0ed21179a29ed28da28057d338e67330ae12123c...          100059
#
#                                           question_text  \
# 0     Is a general or singular causal claim made? Hi...
# 1     What evidence is given for the primary causal ...
# 2     What evidence is given for the primary causal ...
# 3     How representative is the sample of the popula...
# 4     What is the best alternative explanation you c...
# ...                                                 ...
# 1245  Given the information you have, how likely is ...
# 1246  Given the information you have, how likely is ...
# 1247  Does the author suggest in any way that furthe...
# 1248  How difficult was this task for you, on the wh...
# 1249  How confident are you about your answers, on t...
#
#                                             answer_text  start_pos  end_pos
# 0           General Causation (In general, X causes Y.)       3197     3311
# 1                                           Correlation       3375     3384
# 2                                           Correlation       3375     3528
# 3                             Not at all representative          0        0
# 4     Even as the author says, secondary factors can...          0        0
# ...                                                 ...        ...      ...
# 1245                                      Very Unlikely          0        0
# 1246                                  Somewhat Unlikely          0        0
# 1247                                    Yes, implicitly       1023     1106
# 1248                                                  6          0        0
# 1249                                                  9          0        0
#
# [1250 rows x 7 columns]

# %%
convert_to_csv_user_article(clean_data, "85579cf2-e01c-45c5-b9e7-34b40467148d", 100059)

# %% [markdown]
# ## Points based on Topic Name, Question Number, Answer Number

# %% [markdown]
# For beta purposes, we'll filter raw_data by an arbitrary contributor uuid and by the article number 100059, and contributor 00f548b7-6b63-4b47-828e-8e416b6ca0e2, who has the most rows associated with them.

# %%
raw_data.columns
# Out:
# Index(['namespace', 'schema_sha256', 'quiz_task_uuid', 'task_url', 'tua_uuid',
#        'article_batch_name', 'article_number', 'article_filename',
#        'article_sha256', 'article_text_length', 'destination',
#        'task_redundancy', 'taskrun_count', 'quiz_taskrun_uuid',
#        'contributor_uuid', 'created', 'finish_time', 'elapsed_seconds',
#        'topic_name', 'question_label', 'question_text', 'answer_label',
#        'answer_content', 'answer_uuid', 'submitted_tua_uuid', 'answer_text',
#        'case_number', 'highlight_count', 'start_pos', 'end_pos',
#        'target_text'],
#       dtype='object')

# %%
raw_data = raw_data.loc[raw_data["article_number"] == 100059]

raw_data["contributor_uuid"]
b = Counter(raw_data["contributor_uuid"])
most_common_contributor = b.most_common(1)[0][0]
raw_data1 = raw_data.loc[raw_data["contributor_uuid"] == most_common_contributor]
raw_data1
# Out:
#                      namespace  \
# 10    Covid_Evidence2020_03_21
# 11    Covid_Evidence2020_03_21
# 12    Covid_Evidence2020_03_21
# 13    Covid_Evidence2020_03_21
# 14    Covid_Evidence2020_03_21
# ...                        ...
# 1219  Covid_Evidence2020_03_21
# 1220  Covid_Evidence2020_03_21
# 1221  Covid_Evidence2020_03_21
# 1222  Covid_Evidence2020_03_21
# 1223  Covid_Evidence2020_03_21
#
#                                           schema_sha256  \
# 10    45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 11    45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 12    45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 13    45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 14    45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# ...                                                 ...
# 1219  45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 1220  45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 1221  45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 1222  45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
# 1223  45dce5251bd3ea6e908fa33ac9e6a8e17e6830215912ce...
#
#                             quiz_task_uuid  \
# 10    f7562d2d-e884-41f7-8d1c-5163848cb3bf
# 11    f7562d2d-e884-41f7-8d1c-5163848cb3bf
# 12    f7562d2d-e884-41f7-8d1c-5163848cb3bf
# 13    f7562d2d-e884-41f7-8d1c-5163848cb3bf
# 14    f7562d2d-e884-41f7-8d1c-5163848cb3bf
# ...                                    ...
# 1219  edb1510f-1923-4d6f-a678-95f53d752bea
# 1220  edb1510f-1923-4d6f-a678-95f53d752bea
# 1221  edb1510f-1923-4d6f-a678-95f53d752bea
# 1222  edb1510f-1923-4d6f-a678-95f53d752bea
# 1223  edb1510f-1923-4d6f-a678-95f53d752bea
#
#                                                task_url  \
# 10    https://pe.goodlylabs.org/project/Covid_Eviden...
# 11    https://pe.goodlylabs.org/project/Covid_Eviden...
# 12    https://pe.goodlylabs.org/project/Covid_Eviden...
# 13    https://pe.goodlylabs.org/project/Covid_Eviden...
# 14    https://pe.goodlylabs.org/project/Covid_Eviden...
# ...                                                 ...
# 1219  https://pe.goodlylabs.org/project/Covid_Eviden...
# 1220  https://pe.goodlylabs.org/project/Covid_Eviden...
# 1221  https://pe.goodlylabs.org/project/Covid_Eviden...
# 1222  https://pe.goodlylabs.org/project/Covid_Eviden...
# 1223  https://pe.goodlylabs.org/project/Covid_Eviden...
#
#                                   tua_uuid  \
# 10    e406cae2-6cbe-4c06-9ddb-1ed542b98221
# 11    e406cae2-6cbe-4c06-9ddb-1ed542b98221
# 12    e406cae2-6cbe-4c06-9ddb-1ed542b98221
# 13    e406cae2-6cbe-4c06-9ddb-1ed542b98221
# 14    e406cae2-6cbe-4c06-9ddb-1ed542b98221
# ...                                    ...
# 1219  a723537a-f11a-41dd-bf5b-668cef67a5de
# 1220  a723537a-f11a-41dd-bf5b-668cef67a5de
# 1221  a723537a-f11a-41dd-bf5b-668cef67a5de
# 1222  a723537a-f11a-41dd-bf5b-668cef67a5de
# 1223  a723537a-f11a-41dd-bf5b-668cef67a5de
#
#                                 article_batch_name  article_number  \
# 10    CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 11    CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 12    CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 13    CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 14    CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# ...                                            ...             ...
# 1219  CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 1220  CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 1221  CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 1222  CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
# 1223  CovidArticles/Covid_article_for_PE_S&S&S.txt          100059
#
#                     article_filename  \
# 10    Covid_article_for_PE_S&S&S.txt
# 11    Covid_article_for_PE_S&S&S.txt
# 12    Covid_article_for_PE_S&S&S.txt
# 13    Covid_article_for_PE_S&S&S.txt
# 14    Covid_article_for_PE_S&S&S.txt
# ...                              ...
# 1219  Covid_article_for_PE_S&S&S.txt
# 1220  Covid_article_for_PE_S&S&S.txt
# 1221  Covid_article_for_PE_S&S&S.txt
# 1222  Covid_article_for_PE_S&S&S.txt
# 1223  Covid_article_for_PE_S&S&S.txt
#
#                                          article_sha256  article_text_length  \
# 10    4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 11    4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 12    4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 13    4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 14    4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# ...                                                 ...                  ...
# 1219  4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 1220  4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 1221  4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 1222  4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
# 1223  4b537e0ed21179a29ed28da28057d338e67330ae12123c...                 6794
#
#       ... answer_label                               answer_content  \
# 10    ...     T1.Q1.A1  General Causation (In general, X causes Y.)
# 11    ...     T1.Q2.A4            A plausible mechanism is proposed
# 12    ...     T1.Q2.A4            A plausible mechanism is proposed
# 13    ...     T1.Q2.A7                            Experts are cited
# 14    ...     T1.Q2.A7                            Experts are cited
# ...   ...          ...                                          ...
# 1219  ...    T1.Q10.A3                  Neither Likely nor Unlikely
# 1220  ...    T1.Q11.A3                                     Not Sure
# 1221  ...    T1.Q12.A1                              Yes, explicitly
# 1222  ...    T1.Q13.A5                       5: Middling difficulty
# 1223  ...    T1.Q14.A5                                     5: 50-50
#
#                                answer_uuid  \
# 10    73d7a14a-9ec6-404c-b2b7-a55508af3b76
# 11    0546a258-029e-46ed-a84f-9ea36d69a770
# 12    0546a258-029e-46ed-a84f-9ea36d69a770
# 13    c51b597d-2d96-4337-affe-b92836a08869
# 14    c51b597d-2d96-4337-affe-b92836a08869
# ...                                    ...
# 1219  8887f35b-e3c5-4ef9-b87e-ce3ff1fdbfef
# 1220  e7da0f8e-592a-4176-9a96-1352acd29b49
# 1221  4feb3c85-9fc3-442c-a1a3-e3690b887444
# 1222  73d8f381-e2b9-41fd-ac96-e17752b6c26a
# 1223  d4696215-f81b-46da-b965-b9377f68e6bb
#
#                         submitted_tua_uuid  \
# 10    0012187a-a286-4b52-8a7c-e8190880064e
# 11    1c4632df-f052-4090-b67a-4aa9580acad4
# 12    1c4632df-f052-4090-b67a-4aa9580acad4
# 13    801b2e53-d569-49b5-91d6-c416fe295fbd
# 14    801b2e53-d569-49b5-91d6-c416fe295fbd
# ...                                    ...
# 1219  a6362b6e-aae8-4f05-ac5c-18b8eec18118
# 1220  379e2a9d-e2f7-4081-bc18-911523410fc4
# 1221  804c12f6-5454-4ab0-ae89-5dc3de184109
# 1222  81b12b6e-f060-4c6a-9087-c78d9b3e3f44
# 1223  3c30fc7e-58c5-43bb-acd7-94524d8a9514
#
#                                       answer_text case_number highlight_count  \
# 10    General Causation (In general, X causes Y.)           1               1
# 11              A plausible mechanism is proposed           1               2
# 12              A plausible mechanism is proposed           1               2
# 13                              Experts are cited           1               2
# 14                              Experts are cited           1               2
# ...                                           ...         ...             ...
# 1219                  Neither Likely nor Unlikely           0               0
# 1220                                     Not Sure           0               0
# 1221                              Yes, explicitly           1               1
# 1222                       5: Middling difficulty           0               0
# 1223                                     5: 50-50           0               0
#
#       start_pos end_pos                                        target_text
# 10         3197    3528  Health problems associated with social isolati...
# 11         3197    3307  Health problems associated with social isolati...
# 12         3318    3528  Walling people off from one another for months...
# 13         3129    3195  psychiatrist Damir Huremovic of Northwell Heal...
# 14         3583    3702  Huremovic, who cowrote and edited the 2019 boo...
# ...         ...     ...                                                ...
# 1219          0       0                                                NaN
# 1220          0       0                                                NaN
# 1221       1023    1106  Research on the psychological toll of social d...
# 1222          0       0                                                NaN
# 1223          0       0                                                NaN
#
# [105 rows x 31 columns]

# %%
raw_data[['topic_name', 'question_label', 'answer_label']]
# Out:
#                topic_name question_label answer_label
# 0     Evidence Specialist          T1.Q1     T1.Q1.A1
# 1     Evidence Specialist          T1.Q2     T1.Q2.A1
# 2     Evidence Specialist          T1.Q2     T1.Q2.A1
# 3     Evidence Specialist          T1.Q4     T1.Q4.A5
# 4     Evidence Specialist          T1.Q7     T1.Q7.A1
# ...                   ...            ...          ...
# 1245  Evidence Specialist         T1.Q10    T1.Q10.A5
# 1246  Evidence Specialist         T1.Q11    T1.Q11.A4
# 1247  Evidence Specialist         T1.Q12    T1.Q12.A2
# 1248  Evidence Specialist         T1.Q13    T1.Q13.A6
# 1249  Evidence Specialist         T1.Q14    T1.Q14.A9
#
# [1250 rows x 3 columns]

# %%
string = 'T1.Q11.A14'
re.findall('A\d+', string)[0]
# Out:
# 'A14'

# %%
raw_data['answer_label'].apply(lambda x: re.findall('A\d+', x)[0])
# Out:
# 0       A1
# 1       A1
# 2       A1
# 3       A5
# 4       A1
#         ..
# 1245    A5
# 1246    A4
# 1247    A2
# 1248    A6
# 1249    A9
# Name: answer_label, Length: 1250, dtype: object

# %%
raw_data.columns
# Out:
# Index(['namespace', 'schema_sha256', 'quiz_task_uuid', 'task_url', 'tua_uuid',
#        'article_batch_name', 'article_number', 'article_filename',
#        'article_sha256', 'article_text_length', 'destination',
#        'task_redundancy', 'taskrun_count', 'quiz_taskrun_uuid',
#        'contributor_uuid', 'created', 'finish_time', 'elapsed_seconds',
#        'topic_name', 'question_label', 'question_text', 'answer_label',
#        'answer_content', 'answer_uuid', 'submitted_tua_uuid', 'answer_text',
#        'case_number', 'highlight_count', 'start_pos', 'end_pos',
#        'target_text'],
#       dtype='object')

# %%
# Extracts question and answer number of a topic. 
def get_TopicQA(df, row_number):
    select_df = df[['topic_name', 'question_label', 'answer_label', 'start_pos', 'end_pos']].copy()
    select_df['topic_name'] = select_df['topic_name'].apply(lambda x: x.split(' ')[0])
    select_df['question_label'] = select_df['question_label'].apply(lambda x: re.findall('Q\d+', x)[0])
    select_df['answer_label'] = select_df['answer_label'].apply(lambda x: re.findall('A\d+', x)[0])
    select_df = select_df.reset_index()
    return select_df[select_df['index'] == row_number]

# %%
test_row = get_TopicQA(raw_data, 1)
test_row
# Out:
#    index topic_name question_label answer_label  start_pos  end_pos
# 1      1   Evidence             Q2           A1       3375     3384

# %% [markdown]
# need to get points and label from weight key csv
# want point value (col F), topic (category), subset (col G - label)
#  - extract this from weight_key csv (do string parsing - slice out the “Specialist” part)
# into new data frame —> csv — different csv name from previous ones

# %%
weight_key = pd.read_csv('weight_key.csv')

# %%
weight_key.head()
# Out:
#      Schema  Question_Number  Question_Number_V2 Question_Type  Answer_Number  \
# 0  Language              2.0                 NaN       ordinal            1.0
# 1  Language              2.0                 NaN       ordinal            2.0
# 2  Language              2.0                 NaN       ordinal            3.0
# 3  Language              2.0                 NaN       ordinal            4.0
# 4  Language              2.0                 NaN       ordinal            5.0
#
#    Point_Recommendation               Label  Key Question  answer_uuid
# 0                  -4.0  Metaphor unhelpful           NaN          NaN
# 1                  -3.0  Metaphor unhelpful           NaN          NaN
# 2                  -2.0  Metaphor unhelpful           NaN          NaN
# 3                  -1.0  Metaphor unhelpful           NaN          NaN
# 4                   0.0  Metaphor unhelpful           NaN          NaN

# %%
test_df = weight_key[(weight_key['Question_Number'] == 2.0) & (weight_key['Answer_Number'] == 1.0)]
test_df
# Out:
#           Schema  Question_Number  Question_Number_V2 Question_Type  \
# 0       Language              2.0                 NaN       ordinal
# 43     Reasoning              2.0                 NaN   categorical
# 76      Evidence              2.0                 NaN   categorical
# 118  Probability              2.0                 NaN       ordinal
# 152      Overall              2.0                 NaN       ordinal
# 171      Sources              2.0                 NaN       ordinal
#
#      Answer_Number  Point_Recommendation                     Label  \
# 0              1.0                  -4.0        Metaphor unhelpful
# 43             1.0                  -5.0    Availability Heuristic
# 76             1.0                   0.0       Quality of evidence
# 118            1.0                   0.0  Inappropriate confidence
# 152            1.0                  -3.0               Very biased
# 171            1.0                   2.0          Qualified Source
#
#      Key Question  answer_uuid
# 0             NaN          NaN
# 43            NaN          NaN
# 76            NaN          NaN
# 118           NaN          NaN
# 152           NaN          NaN
# 171           NaN          NaN

# %%
# Gets points and label from csv.
def new_from_row(df, row_number):
    
    TQA_row = get_TopicQA(df, row_number)
    
    TQA_question = int(TQA_row['question_label'][row_number][1:])
    TQA_answer = int(TQA_row['answer_label'][row_number][1:])
    TQA_schema = TQA_row['topic_name'][row_number]
    new_df = weight_key[(weight_key['Question_Number'] == float(TQA_question)) & (weight_key['Answer_Number'] == float(TQA_answer)) & (weight_key['Schema'] == TQA_schema)]
    if new_df.empty:
        raise Exception("There is no algorithm output for this Tagworks task.")
    else:
        new_df = new_df.drop(columns=['Question_Number_V2', 'Question_Type', 'Key Question', 'answer_uuid'])
        new_df = new_df.rename(columns={'Question_Number': 'Question Number', 'Answer_Number':'Answer Number', 'Point_Recommendation': 'Point Recommendation', "Schema": "Credibility Indicator Category", "Label": "Credibility Indicator Name"})
        new_df['Start'] = np.array(TQA_row['start_pos'])
        new_df['End'] = np.array(TQA_row['end_pos'])
        return new_df

# %%
new_df = new_from_row(raw_data, 1)
new_df
# Out:
#    Credibility Indicator Category  Question Number  Answer Number  \
# 76                       Evidence              2.0            1.0
#
#     Point Recommendation Credibility Indicator Name  Start   End
# 76                   0.0        Quality of evidence   3375  3384

# %%
for row_num in range(2, len(raw_data)):
    try:
        new_row = new_from_row(raw_data, row_num)
    except Exception as error:
        continue
    new_df = new_df.append(new_from_row(raw_data, row_num))
new_df
# Out:
#     Credibility Indicator Category  Question Number  Answer Number  \
# 76                        Evidence              2.0            1.0
# 76                        Evidence              2.0            1.0
# 89                        Evidence              4.0            5.0
# 99                        Evidence              8.0            1.0
# 117                       Evidence             12.0            4.0
# ..                             ...              ...            ...
# 97                        Evidence              6.0            2.0
# 103                       Evidence              8.0            5.0
# 108                       Evidence             10.0            5.0
# 112                       Evidence             11.0            4.0
# 115                       Evidence             12.0            2.0
#
#      Point Recommendation Credibility Indicator Name  Start   End
# 76                    0.0        Quality of evidence   3375  3384
# 76                    0.0        Quality of evidence   3375  3528
# 89                   -4.0  Sample representativeness      0     0
# 99                   -4.0    Alternative explanation      0     0
# 117                   0.0           Open to evidence      0     0
# ..                    ...                        ...    ...   ...
# 97                   -2.0      Randomized Assignment      0     0
# 103                   0.0    Alternative explanation      0     0
# 108                   0.0    Statistical uncertainty      0     0
# 112                  -0.5     Systematic uncertainty      0     0
# 115                   1.0           Open to evidence   1023  1106
#
# [609 rows x 7 columns]

# %% [markdown]
# Now we group by the schema and label--this is just to simplify the work that we do on the front end.

# %%
new_df.to_csv("aggregate_datahunts/100059_"+most_common_contributor+"_user_contributions.csv")

# %%
most_common_contributor
# Out:
# '00f548b7-6b63-4b47-828e-8e416b6ca0e2'
